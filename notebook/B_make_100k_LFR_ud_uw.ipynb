# %%
import gct
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %%
size=32

sizes=[]
while True:
    sizes.append(size)
    if size>200*1000:
        break        
    size=int(size*1.2)

# %%
len(sizes)
# Out:
# 50

# %%
sizes
# Out:
# [32,
#  38,
#  45,
#  54,
#  64,
#  76,
#  91,
#  109,
#  130,
#  156,
#  187,
#  224,
#  268,
#  321,
#  385,
#  462,
#  554,
#  664,
#  796,
#  955,
#  1146,
#  1375,
#  1650,
#  1980,
#  2376,
#  2851,
#  3421,
#  4105,
#  4926,
#  5911,
#  7093,
#  8511,
#  10213,
#  12255,
#  14706,
#  17647,
#  21176,
#  25411,
#  30493,
#  36591,
#  43909,
#  52690,
#  63228,
#  75873,
#  91047,
#  109256,
#  131107,
#  157328,
#  188793,
#  226551]

# %%
def setup_data(N):
    name = "LFR_ud_wu_N"+str(N)
    graph_unweighted_undirect = gct.random_dataset.generate_undirected_unweighted_random_graph_LFR(name=name, \
                                       N=N, k=int(N/4), maxk=int(N/2), mu=0.2, minc=int(N/10))
def make_graph(size):
    setup_data(size)

# %%
for size in sizes:
    make_graph(size)
# Out:
# 2020-04-25 01:29:29,172 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 3 -mu 0.2 -maxk 16 -k 8 -N 32'  with seed 884793
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 3 -mu 0.2 -maxk 16 -k 8 -N 32'  with seed 884793
# 2020-04-25 01:29:29,173 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpo4ainak8
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpo4ainak8
# 2020-04-25 01:29:29,205 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# /opt/conda/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
# 2020-04-25 01:29:29,223 - Dataset:LFR_ud_wu_N32 - INFO - writing/data/data/LFR_ud_wu_N32/edges.parq
# INFO:Dataset:LFR_ud_wu_N32:writing/data/data/LFR_ud_wu_N32/edges.parq
# 2020-04-25 01:29:29,915 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N32/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N32/gt_default.parq
# 2020-04-25 01:29:29,922 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 3 -mu 0.2 -maxk 19 -k 9 -N 38'  with seed 639990
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 3 -mu 0.2 -maxk 19 -k 9 -N 38'  with seed 639990
# 2020-04-25 01:29:29,923 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpu7u7_0n4
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpu7u7_0n4
# 2020-04-25 01:29:29,951 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# /opt/conda/envs/python3/lib/python3.6/site-packages/pandas/core/frame.py:4238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
# 2020-04-25 01:29:29,970 - Dataset:LFR_ud_wu_N38 - INFO - writing/data/data/LFR_ud_wu_N38/edges.parq
# INFO:Dataset:LFR_ud_wu_N38:writing/data/data/LFR_ud_wu_N38/edges.parq
# 2020-04-25 01:29:29,976 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N38/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N38/gt_default.parq
# 2020-04-25 01:29:29,986 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 4 -mu 0.2 -maxk 22 -k 11 -N 45'  with seed 5393
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 4 -mu 0.2 -maxk 22 -k 11 -N 45'  with seed 5393
# 2020-04-25 01:29:29,988 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpwvbdat2z
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpwvbdat2z
# 2020-04-25 01:29:30,022 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:30,039 - Dataset:LFR_ud_wu_N45 - INFO - writing/data/data/LFR_ud_wu_N45/edges.parq
# INFO:Dataset:LFR_ud_wu_N45:writing/data/data/LFR_ud_wu_N45/edges.parq
# 2020-04-25 01:29:30,046 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N45/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N45/gt_default.parq
# 2020-04-25 01:29:30,054 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 5 -mu 0.2 -maxk 27 -k 13 -N 54'  with seed 908595
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 5 -mu 0.2 -maxk 27 -k 13 -N 54'  with seed 908595
# 2020-04-25 01:29:30,058 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpidqo5d1k
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpidqo5d1k
# 2020-04-25 01:29:30,091 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:30,107 - Dataset:LFR_ud_wu_N54 - INFO - writing/data/data/LFR_ud_wu_N54/edges.parq
# INFO:Dataset:LFR_ud_wu_N54:writing/data/data/LFR_ud_wu_N54/edges.parq
# 2020-04-25 01:29:30,114 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N54/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N54/gt_default.parq
# 2020-04-25 01:29:30,122 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 6 -mu 0.2 -maxk 32 -k 16 -N 64'  with seed 667589
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 6 -mu 0.2 -maxk 32 -k 16 -N 64'  with seed 667589
# 2020-04-25 01:29:30,125 - RandomGenerator:LFR - INFO - working dir: /tmp/tmp7zs80itb
# INFO:RandomGenerator:LFR:working dir: /tmp/tmp7zs80itb
# 2020-04-25 01:29:30,163 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:30,180 - Dataset:LFR_ud_wu_N64 - INFO - writing/data/data/LFR_ud_wu_N64/edges.parq
# INFO:Dataset:LFR_ud_wu_N64:writing/data/data/LFR_ud_wu_N64/edges.parq
# 2020-04-25 01:29:30,187 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N64/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N64/gt_default.parq
# 2020-04-25 01:29:30,196 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 7 -mu 0.2 -maxk 38 -k 19 -N 76'  with seed 508573
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 7 -mu 0.2 -maxk 38 -k 19 -N 76'  with seed 508573
# 2020-04-25 01:29:30,199 - RandomGenerator:LFR - INFO - working dir: /tmp/tmp3llvyxac
# INFO:RandomGenerator:LFR:working dir: /tmp/tmp3llvyxac
# 2020-04-25 01:29:30,244 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:30,262 - Dataset:LFR_ud_wu_N76 - INFO - writing/data/data/LFR_ud_wu_N76/edges.parq
# INFO:Dataset:LFR_ud_wu_N76:writing/data/data/LFR_ud_wu_N76/edges.parq
# 2020-04-25 01:29:30,271 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N76/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N76/gt_default.parq
# 2020-04-25 01:29:30,278 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 9 -mu 0.2 -maxk 45 -k 22 -N 91'  with seed 587988
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 9 -mu 0.2 -maxk 45 -k 22 -N 91'  with seed 587988
# 2020-04-25 01:29:30,281 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpl3k76cai
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpl3k76cai
# 2020-04-25 01:29:30,335 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:30,354 - Dataset:LFR_ud_wu_N91 - INFO - writing/data/data/LFR_ud_wu_N91/edges.parq
# INFO:Dataset:LFR_ud_wu_N91:writing/data/data/LFR_ud_wu_N91/edges.parq
# 2020-04-25 01:29:30,363 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N91/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N91/gt_default.parq
# 2020-04-25 01:29:30,369 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 10 -mu 0.2 -maxk 54 -k 27 -N 109'  with seed 520252
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 10 -mu 0.2 -maxk 54 -k 27 -N 109'  with seed 520252
# 2020-04-25 01:29:30,373 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpueinzcme
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpueinzcme
# 2020-04-25 01:29:30,439 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:30,458 - Dataset:LFR_ud_wu_N109 - INFO - writing/data/data/LFR_ud_wu_N109/edges.parq
# INFO:Dataset:LFR_ud_wu_N109:writing/data/data/LFR_ud_wu_N109/edges.parq
# 2020-04-25 01:29:30,464 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N109/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N109/gt_default.parq
# 2020-04-25 01:29:30,471 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 13 -mu 0.2 -maxk 65 -k 32 -N 130'  with seed 380554
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 13 -mu 0.2 -maxk 65 -k 32 -N 130'  with seed 380554
# 2020-04-25 01:29:30,472 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpnkxgt3qu
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpnkxgt3qu
# 2020-04-25 01:29:30,563 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:30,581 - Dataset:LFR_ud_wu_N130 - INFO - writing/data/data/LFR_ud_wu_N130/edges.parq
# INFO:Dataset:LFR_ud_wu_N130:writing/data/data/LFR_ud_wu_N130/edges.parq
# 2020-04-25 01:29:30,589 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N130/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N130/gt_default.parq
# 2020-04-25 01:29:30,597 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 15 -mu 0.2 -maxk 78 -k 39 -N 156'  with seed 863870
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 15 -mu 0.2 -maxk 78 -k 39 -N 156'  with seed 863870
# 2020-04-25 01:29:30,600 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpplxdmtfm
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpplxdmtfm
# 2020-04-25 01:29:30,749 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:30,767 - Dataset:LFR_ud_wu_N156 - INFO - writing/data/data/LFR_ud_wu_N156/edges.parq
# INFO:Dataset:LFR_ud_wu_N156:writing/data/data/LFR_ud_wu_N156/edges.parq
# 2020-04-25 01:29:30,774 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N156/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N156/gt_default.parq
# 2020-04-25 01:29:30,780 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 18 -mu 0.2 -maxk 93 -k 46 -N 187'  with seed 870040
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 18 -mu 0.2 -maxk 93 -k 46 -N 187'  with seed 870040
# 2020-04-25 01:29:30,782 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpgo12fyyt
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpgo12fyyt
# 2020-04-25 01:29:31,092 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:31,109 - Dataset:LFR_ud_wu_N187 - INFO - writing/data/data/LFR_ud_wu_N187/edges.parq
# INFO:Dataset:LFR_ud_wu_N187:writing/data/data/LFR_ud_wu_N187/edges.parq
# 2020-04-25 01:29:31,116 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N187/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N187/gt_default.parq
# 2020-04-25 01:29:31,122 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 22 -mu 0.2 -maxk 112 -k 56 -N 224'  with seed 673545
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 22 -mu 0.2 -maxk 112 -k 56 -N 224'  with seed 673545
# 2020-04-25 01:29:31,123 - RandomGenerator:LFR - INFO - working dir: /tmp/tmp2vpxdk3z
# INFO:RandomGenerator:LFR:working dir: /tmp/tmp2vpxdk3z
# 2020-04-25 01:29:31,435 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:31,452 - Dataset:LFR_ud_wu_N224 - INFO - writing/data/data/LFR_ud_wu_N224/edges.parq
# INFO:Dataset:LFR_ud_wu_N224:writing/data/data/LFR_ud_wu_N224/edges.parq
# 2020-04-25 01:29:31,459 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N224/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N224/gt_default.parq
# 2020-04-25 01:29:31,465 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 26 -mu 0.2 -maxk 134 -k 67 -N 268'  with seed 420180
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 26 -mu 0.2 -maxk 134 -k 67 -N 268'  with seed 420180
# 2020-04-25 01:29:31,467 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpbuqx6q2x
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpbuqx6q2x
# 2020-04-25 01:29:32,260 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:32,280 - Dataset:LFR_ud_wu_N268 - INFO - writing/data/data/LFR_ud_wu_N268/edges.parq
# INFO:Dataset:LFR_ud_wu_N268:writing/data/data/LFR_ud_wu_N268/edges.parq
# 2020-04-25 01:29:32,288 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N268/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N268/gt_default.parq
# 2020-04-25 01:29:32,296 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 32 -mu 0.2 -maxk 160 -k 80 -N 321'  with seed 937112
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 32 -mu 0.2 -maxk 160 -k 80 -N 321'  with seed 937112
# 2020-04-25 01:29:32,298 - RandomGenerator:LFR - INFO - working dir: /tmp/tmph2erp1hm
# INFO:RandomGenerator:LFR:working dir: /tmp/tmph2erp1hm
# 2020-04-25 01:29:33,076 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:33,096 - Dataset:LFR_ud_wu_N321 - INFO - writing/data/data/LFR_ud_wu_N321/edges.parq
# INFO:Dataset:LFR_ud_wu_N321:writing/data/data/LFR_ud_wu_N321/edges.parq
# 2020-04-25 01:29:33,104 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N321/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N321/gt_default.parq
# 2020-04-25 01:29:33,110 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 38 -mu 0.2 -maxk 192 -k 96 -N 385'  with seed 256354
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 38 -mu 0.2 -maxk 192 -k 96 -N 385'  with seed 256354
# 2020-04-25 01:29:33,112 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpezgr2o7a
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpezgr2o7a
# 2020-04-25 01:29:34,515 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:34,538 - Dataset:LFR_ud_wu_N385 - INFO - writing/data/data/LFR_ud_wu_N385/edges.parq
# INFO:Dataset:LFR_ud_wu_N385:writing/data/data/LFR_ud_wu_N385/edges.parq
# 2020-04-25 01:29:34,548 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N385/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N385/gt_default.parq
# 2020-04-25 01:29:34,556 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 46 -mu 0.2 -maxk 231 -k 115 -N 462'  with seed 585242
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 46 -mu 0.2 -maxk 231 -k 115 -N 462'  with seed 585242
# 2020-04-25 01:29:34,558 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpf8hkvh5j
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpf8hkvh5j
# 2020-04-25 01:29:36,994 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:37,019 - Dataset:LFR_ud_wu_N462 - INFO - writing/data/data/LFR_ud_wu_N462/edges.parq
# INFO:Dataset:LFR_ud_wu_N462:writing/data/data/LFR_ud_wu_N462/edges.parq
# 2020-04-25 01:29:37,029 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N462/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N462/gt_default.parq
# 2020-04-25 01:29:37,037 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 55 -mu 0.2 -maxk 277 -k 138 -N 554'  with seed 261202
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 55 -mu 0.2 -maxk 277 -k 138 -N 554'  with seed 261202
# 2020-04-25 01:29:37,040 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpnstay0p1
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpnstay0p1
# 2020-04-25 01:29:43,392 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:43,423 - Dataset:LFR_ud_wu_N554 - INFO - writing/data/data/LFR_ud_wu_N554/edges.parq
# INFO:Dataset:LFR_ud_wu_N554:writing/data/data/LFR_ud_wu_N554/edges.parq
# 2020-04-25 01:29:43,431 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N554/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N554/gt_default.parq
# 2020-04-25 01:29:43,440 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 66 -mu 0.2 -maxk 332 -k 166 -N 664'  with seed 832732
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 66 -mu 0.2 -maxk 332 -k 166 -N 664'  with seed 832732
# 2020-04-25 01:29:43,443 - RandomGenerator:LFR - INFO - working dir: /tmp/tmp6qjh2fzy
# INFO:RandomGenerator:LFR:working dir: /tmp/tmp6qjh2fzy
# 2020-04-25 01:29:50,222 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:29:50,254 - Dataset:LFR_ud_wu_N664 - INFO - writing/data/data/LFR_ud_wu_N664/edges.parq
# INFO:Dataset:LFR_ud_wu_N664:writing/data/data/LFR_ud_wu_N664/edges.parq
# 2020-04-25 01:29:50,264 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N664/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N664/gt_default.parq
# 2020-04-25 01:29:50,272 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 79 -mu 0.2 -maxk 398 -k 199 -N 796'  with seed 922713
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 79 -mu 0.2 -maxk 398 -k 199 -N 796'  with seed 922713
# 2020-04-25 01:29:50,275 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpwa7jcxs3
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpwa7jcxs3
# 2020-04-25 01:30:01,454 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:30:01,494 - Dataset:LFR_ud_wu_N796 - INFO - writing/data/data/LFR_ud_wu_N796/edges.parq
# INFO:Dataset:LFR_ud_wu_N796:writing/data/data/LFR_ud_wu_N796/edges.parq
# 2020-04-25 01:30:01,506 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N796/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N796/gt_default.parq
# 2020-04-25 01:30:01,516 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 95 -mu 0.2 -maxk 477 -k 238 -N 955'  with seed 437817
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 95 -mu 0.2 -maxk 477 -k 238 -N 955'  with seed 437817
# 2020-04-25 01:30:01,517 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpq665l7ht
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpq665l7ht
# 2020-04-25 01:30:40,100 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:30:40,139 - Dataset:LFR_ud_wu_N955 - INFO - writing/data/data/LFR_ud_wu_N955/edges.parq
# INFO:Dataset:LFR_ud_wu_N955:writing/data/data/LFR_ud_wu_N955/edges.parq
# 2020-04-25 01:30:40,152 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N955/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N955/gt_default.parq
# 2020-04-25 01:30:40,159 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 114 -mu 0.2 -maxk 573 -k 286 -N 1146'  with seed 811264
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 114 -mu 0.2 -maxk 573 -k 286 -N 1146'  with seed 811264
# 2020-04-25 01:30:40,160 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpupn_82o4
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpupn_82o4
# 2020-04-25 01:31:50,551 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:31:50,619 - Dataset:LFR_ud_wu_N1146 - INFO - writing/data/data/LFR_ud_wu_N1146/edges.parq
# INFO:Dataset:LFR_ud_wu_N1146:writing/data/data/LFR_ud_wu_N1146/edges.parq
# 2020-04-25 01:31:50,637 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N1146/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N1146/gt_default.parq
# 2020-04-25 01:31:50,646 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 137 -mu 0.2 -maxk 687 -k 343 -N 1375'  with seed 31482
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 137 -mu 0.2 -maxk 687 -k 343 -N 1375'  with seed 31482
# 2020-04-25 01:31:50,648 - RandomGenerator:LFR - INFO - working dir: /tmp/tmplqzmgn5h
# INFO:RandomGenerator:LFR:working dir: /tmp/tmplqzmgn5h
# 2020-04-25 01:33:29,737 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:33:29,835 - Dataset:LFR_ud_wu_N1375 - INFO - writing/data/data/LFR_ud_wu_N1375/edges.parq
# INFO:Dataset:LFR_ud_wu_N1375:writing/data/data/LFR_ud_wu_N1375/edges.parq
# 2020-04-25 01:33:29,857 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N1375/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N1375/gt_default.parq
# 2020-04-25 01:33:29,869 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 165 -mu 0.2 -maxk 825 -k 412 -N 1650'  with seed 796129
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 165 -mu 0.2 -maxk 825 -k 412 -N 1650'  with seed 796129
# 2020-04-25 01:33:29,870 - RandomGenerator:LFR - INFO - working dir: /tmp/tmp8rotx8so
# INFO:RandomGenerator:LFR:working dir: /tmp/tmp8rotx8so
# 2020-04-25 01:38:09,345 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:38:09,493 - Dataset:LFR_ud_wu_N1650 - INFO - writing/data/data/LFR_ud_wu_N1650/edges.parq
# INFO:Dataset:LFR_ud_wu_N1650:writing/data/data/LFR_ud_wu_N1650/edges.parq
# 2020-04-25 01:38:09,527 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N1650/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N1650/gt_default.parq
# 2020-04-25 01:38:09,535 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 198 -mu 0.2 -maxk 990 -k 495 -N 1980'  with seed 458537
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 198 -mu 0.2 -maxk 990 -k 495 -N 1980'  with seed 458537
# 2020-04-25 01:38:09,536 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpx55q7bl7
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpx55q7bl7
# 2020-04-25 01:42:55,143 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:42:55,318 - Dataset:LFR_ud_wu_N1980 - INFO - writing/data/data/LFR_ud_wu_N1980/edges.parq
# INFO:Dataset:LFR_ud_wu_N1980:writing/data/data/LFR_ud_wu_N1980/edges.parq
# 2020-04-25 01:42:55,362 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N1980/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N1980/gt_default.parq
# 2020-04-25 01:42:55,376 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 237 -mu 0.2 -maxk 1188 -k 594 -N 2376'  with seed 396545
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 237 -mu 0.2 -maxk 1188 -k 594 -N 2376'  with seed 396545
# 2020-04-25 01:42:55,377 - RandomGenerator:LFR - INFO - working dir: /tmp/tmp4vcrei5m
# INFO:RandomGenerator:LFR:working dir: /tmp/tmp4vcrei5m
# 2020-04-25 01:51:59,796 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 01:52:00,017 - Dataset:LFR_ud_wu_N2376 - INFO - writing/data/data/LFR_ud_wu_N2376/edges.parq
# INFO:Dataset:LFR_ud_wu_N2376:writing/data/data/LFR_ud_wu_N2376/edges.parq
# 2020-04-25 01:52:00,072 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N2376/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N2376/gt_default.parq
# 2020-04-25 01:52:00,083 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 285 -mu 0.2 -maxk 1425 -k 712 -N 2851'  with seed 690785
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 285 -mu 0.2 -maxk 1425 -k 712 -N 2851'  with seed 690785
# 2020-04-25 01:52:00,084 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpm6p0c4fi
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpm6p0c4fi
# 2020-04-25 02:19:59,125 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 02:19:59,573 - Dataset:LFR_ud_wu_N2851 - INFO - writing/data/data/LFR_ud_wu_N2851/edges.parq
# INFO:Dataset:LFR_ud_wu_N2851:writing/data/data/LFR_ud_wu_N2851/edges.parq
# 2020-04-25 02:19:59,662 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N2851/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N2851/gt_default.parq
# 2020-04-25 02:19:59,677 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 342 -mu 0.2 -maxk 1710 -k 855 -N 3421'  with seed 114118
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 342 -mu 0.2 -maxk 1710 -k 855 -N 3421'  with seed 114118
# 2020-04-25 02:19:59,678 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpkdb7jaru
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpkdb7jaru
# 2020-04-25 03:02:03,396 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 03:02:04,053 - Dataset:LFR_ud_wu_N3421 - INFO - writing/data/data/LFR_ud_wu_N3421/edges.parq
# INFO:Dataset:LFR_ud_wu_N3421:writing/data/data/LFR_ud_wu_N3421/edges.parq
# 2020-04-25 03:02:04,202 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N3421/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N3421/gt_default.parq
# 2020-04-25 03:02:04,220 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 410 -mu 0.2 -maxk 2052 -k 1026 -N 4105'  with seed 262082
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 410 -mu 0.2 -maxk 2052 -k 1026 -N 4105'  with seed 262082
# 2020-04-25 03:02:04,221 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpzy2xezuc
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpzy2xezuc
# 2020-04-25 03:59:08,489 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 03:59:09,740 - Dataset:LFR_ud_wu_N4105 - INFO - writing/data/data/LFR_ud_wu_N4105/edges.parq
# INFO:Dataset:LFR_ud_wu_N4105:writing/data/data/LFR_ud_wu_N4105/edges.parq
# 2020-04-25 03:59:09,957 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N4105/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N4105/gt_default.parq
# 2020-04-25 03:59:09,966 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 492 -mu 0.2 -maxk 2463 -k 1231 -N 4926'  with seed 503527
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 492 -mu 0.2 -maxk 2463 -k 1231 -N 4926'  with seed 503527
# 2020-04-25 03:59:09,970 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpkkyytpoi
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpkkyytpoi
# 2020-04-25 05:46:39,473 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 05:46:41,277 - Dataset:LFR_ud_wu_N4926 - INFO - writing/data/data/LFR_ud_wu_N4926/edges.parq
# INFO:Dataset:LFR_ud_wu_N4926:writing/data/data/LFR_ud_wu_N4926/edges.parq
# 2020-04-25 05:46:41,718 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N4926/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N4926/gt_default.parq
# 2020-04-25 05:46:41,728 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 591 -mu 0.2 -maxk 2955 -k 1477 -N 5911'  with seed 672973
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 591 -mu 0.2 -maxk 2955 -k 1477 -N 5911'  with seed 672973
# 2020-04-25 05:46:41,730 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpxg0yk8dc
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpxg0yk8dc
# 2020-04-25 10:37:43,746 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 10:37:45,764 - Dataset:LFR_ud_wu_N5911 - INFO - writing/data/data/LFR_ud_wu_N5911/edges.parq
# INFO:Dataset:LFR_ud_wu_N5911:writing/data/data/LFR_ud_wu_N5911/edges.parq
# 2020-04-25 10:37:46,304 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N5911/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N5911/gt_default.parq
# 2020-04-25 10:37:46,311 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 709 -mu 0.2 -maxk 3546 -k 1773 -N 7093'  with seed 634403
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 709 -mu 0.2 -maxk 3546 -k 1773 -N 7093'  with seed 634403
# 2020-04-25 10:37:46,312 - RandomGenerator:LFR - INFO - working dir: /tmp/tmp6mnm5vdl
# INFO:RandomGenerator:LFR:working dir: /tmp/tmp6mnm5vdl
# 2020-04-25 17:59:01,498 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-25 17:59:04,396 - Dataset:LFR_ud_wu_N7093 - INFO - writing/data/data/LFR_ud_wu_N7093/edges.parq
# INFO:Dataset:LFR_ud_wu_N7093:writing/data/data/LFR_ud_wu_N7093/edges.parq
# 2020-04-25 17:59:05,183 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N7093/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N7093/gt_default.parq
# 2020-04-25 17:59:05,190 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 851 -mu 0.2 -maxk 4255 -k 2127 -N 8511'  with seed 810991
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 851 -mu 0.2 -maxk 4255 -k 2127 -N 8511'  with seed 810991
# 2020-04-25 17:59:05,191 - RandomGenerator:LFR - INFO - working dir: /tmp/tmpepwm2h2k
# INFO:RandomGenerator:LFR:working dir: /tmp/tmpepwm2h2k
# 2020-04-26 04:24:19,492 - RandomGenerator:LFR - INFO - min node is 1. will make it 0
# INFO:RandomGenerator:LFR:min node is 1. will make it 0
# 2020-04-26 04:24:26,495 - Dataset:LFR_ud_wu_N8511 - INFO - writing/data/data/LFR_ud_wu_N8511/edges.parq
# INFO:Dataset:LFR_ud_wu_N8511:writing/data/data/LFR_ud_wu_N8511/edges.parq
# 2020-04-26 04:24:28,069 - Clustering - INFO - Writing /data/data/LFR_ud_wu_N8511/gt_default.parq
# INFO:Clustering:Writing /data/data/LFR_ud_wu_N8511/gt_default.parq
# 2020-04-26 04:24:28,091 - RandomGenerator:LFR - INFO - Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 1021 -mu 0.2 -maxk 5106 -k 2553 -N 10213'  with seed 854168
# INFO:RandomGenerator:LFR:Runing '/opt/gct/submodules/CommunityDetectionCodes/lfr_undir_net -minc 1021 -mu 0.2 -maxk 5106 -k 2553 -N 10213'  with seed 854168
# 2020-04-26 04:24:28,098 - RandomGenerator:LFR - INFO - working dir: /tmp/tmp1cnz2hba
# INFO:RandomGenerator:LFR:working dir: /tmp/tmp1cnz2hba
